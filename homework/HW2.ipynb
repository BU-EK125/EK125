# %% [markdown]
# # Homework 2: Strings and Lists
#
# **Individually.** This assignment covers material from Class 2: string
# operations, list manipulation, and basic data processing.
#
# Run ALL code cells before submitting, use good programming practices, and
# match the output format exactly as shown in the examples for each problem.
#
# It's important to be consistent with code formatting and patterns because
# consistency makes it much easier for a human to move around a code base
# fluidly and effectively, without having to adjust to different formatting
# patterns as they go.

# %% [markdown]
# ## Problem 1: Personal Information Processor
#
# Write a program that processes personal information stored as strings and
# lists.
#
# See the reading's [Common String Operations](https://BU-EK125.github.io/EK125/class/Class2.html#common-string-operations) and [Modifying Lists](https://BU-EK125.github.io/EK125/class/Class2.html#modifying-lists) sections for a refresher.
#
# 🚩 **Common mistake:** `list.sort()` sorts the list **in place** and
# returns `None` -- writing `hobbies = hobbies.sort()` throws away your
# whole list, replacing it with `None`. Call `hobbies.sort()` on its own
# line, then use `hobbies` afterward; don't reassign it from the call.
#
# **Expected Output:**
# ```
# First name: Jane
# Middle name: Marie
# Last name: Smith
# Initials: J.M.S.
# Updated hobbies: ['coding', 'cooking', 'photography', 'reading', 'swimming']
# Username: jane.smith
# ```

# %%
# Given data:
fullName = "Jane Marie Smith"
hobbies = ["reading", "swimming", "cooking", "photography"]
email = "jane.smith@university.edu"

# Your tasks:
# 1. Extract and print the first name, middle name, and last name separately
# 2. Print the person's initials (J.M.S.)
# 3. Add "coding" to the hobbies list
# 4. Print the hobbies in alphabetical order (look up the sort() method)
# 5. Extract the username from the email (part before @)

# %% [markdown]
# ## Problem 2: Shopping List Manager
#
# Create a simple shopping list manager using lists.
#
# See the reading's [Modifying Lists](https://BU-EK125.github.io/EK125/class/Class2.html#modifying-lists) and [Membership Testing](https://BU-EK125.github.io/EK125/class/Class2.html#membership-testing) sections for a refresher.
#
# **Expected Output:**
# ```
# Current list: ['milk', 'bread', 'eggs', 'apples']
# Length: 4
# After modifications: ['milk', 'butter', 'eggs', 'apples']
# Number of eggs: 1
# Number of spam: 0
# Total cost: $10.75
# ```

# %%
# Start with an empty shopping list
shoppingList = []

# Write code to:
# 1. Add these items: "milk", "bread", "eggs", "apples"
# 2. Print the current list and its length
# 3. Remove "bread" from the list
# 4. Insert "butter" at the second position (index 1)
# 5. Check if "eggs" is in the list, and print how many times
# 6. Check if "spam" is in the list, and print how many times
# 7. Print the final list

# Your code here:


# Then create a second list with prices:
prices = [2.50, 1.25, 3.00, 4.00]  # corresponding to your final items

# 8. Calculate and print the total cost

# Your code here

# %% [markdown]
# ## Problem 3: Text Message Analyzer
#
# Analyze text messages using string operations.
#
# See the reading's [Common String Operations](https://BU-EK125.github.io/EK125/class/Class2.html#common-string-operations) section for a refresher.
#
# **Your output should show:**
# - Character count: 55
# - Word count: 11
# - Sentence count: 3
# - Clean message: "hey how are you doing hope youre having a great day"
# - First word: "hey"
# - Last word: "day"

# %%
message = "Hey! How are you doing? Hope you're having a great day!"

# Write code to:
# 1. Count the total number of characters (including spaces)
# 2. Count the number of words
# 3. Count how many sentences there are (hint: count punctuation marks . ! ?)
# 4. Create a "clean" version with no punctuation (replace ! ? . ' with empty string)
# 5. Convert the clean version to all lowercase
# 6. Create a list of all words from the clean, lowercase version
# 7. Print the first word and last word from your word list

# Your code here:
