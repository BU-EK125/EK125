# %% [markdown]
# # Homework 1: Variables, Types, and Assignments
#
# **Individually.** This assignment covers material from Class 1: creating
# variables, arithmetic operators, type checking, and good programming
# practice.
#
# Run your code before you turn it in to make sure it works -- turn in the
# version with all cells run so any output from your code is visible.

# %% [markdown]
# ## Problem 1
#
# Create two variables: `your_name` and `your_age`. Use `print()` to display
# a sentence introducing yourself. Use good coding practices.
#
# See the reading's [Declaring Variables in Python](https://BU-EK125.github.io/EK125/class/Class1.html#declaring-variables-in-python) and [print(): Displaying Output](https://BU-EK125.github.io/EK125/class/Class1.html#print-displaying-output) sections for a refresher.

# %%
# Your code here

# %% [markdown]
# ## Problem 2
#
# Given `x = 9` and `y = 4`, calculate and print:
# - their sum
# - product
# - result of float division
# - result of integer division (`//`)
# - remainder (`%`)
#
# What should the resulting values and variable types be? Predict these
# before running your code. Use your code to check the types too.
#
# See the reading's [Arithmetic Operators](https://BU-EK125.github.io/EK125/class/Class1.html#arithmetic-operators) and [type(): Checking a Variable's Data Type](https://BU-EK125.github.io/EK125/class/Class1.html#type-checking-a-variables-data-type) sections for a refresher.
#
# 🚩 **Common mistake:** confusing `/` (float division, always returns a
# `float`) with `//` (integer/floor division, returns an `int` when both
# operands are `int`). `9 / 4` is `2.25`; `9 // 4` is `2` -- these are not
# interchangeable, and using the wrong one silently gives a plausible-looking
# but wrong answer rather than an error.

# %% [markdown]
# Double-click this box to enter your predicted values/types here:

# %%
# Your code here

# %% [markdown]
# ## Problem 3
#
# You're working in the lab and you find that you need to mix solutions of
# differing concentrations together. You do this a lot, and it's tedious to
# keep calculating the concentration of the final solution by hand, so you
# want to write code to do it for you. Write code that takes the
# concentration and volume of each of the two solutions and calculates the
# concentration of the final solution. Use good programming practice.
# (NOTE: We could do this using functions, but we haven't learned those
# yet -- just write it as a straight-line script for now.)
#
# See the reading's [Break Down Complex Problems](https://BU-EK125.github.io/EK125/class/Class1.html#break-down-complex-problems) section for a refresher.
#
# 🚩 **Common mistake:** writing the final-concentration formula without parentheses around each numerator/denominator group. `(c1*v1 + c2*v2) / (v1 + v2)` and `c1*v1 + c2*v2 / v1 + v2` are very different calculations -- Python's operator precedence does `/` before `+`, so the second version divides only `c2*v2` by `v1`, then adds the rest.

# %%
# Your code here

# %% [markdown]
# ## Problem 4
#
# In EK131, a main function of the required project is to read the ambient
# room temperature using a TMP36 temperature sensor and to print that
# temperature in degrees C and/or degrees F. Let's write code to accomplish
# this task in python. Since the temperature from the TMP36 will be a
# voltage from 0 to 5V, use the `input()` function to ask the user for a
# voltage in that range, then convert it to temperature using the following
# data table.
#
# ![TMP35/TMP36/TMP37 Output Characteristics](media/HW1_tmp36_table.png)
#
# Print the resulting temperature in both degrees C and degrees F. Use the
# good coding practices we talked about in class.
#
# 🚩 **Common mistake:** the table's offset voltage is given in **volts**
# (0.5 V for the TMP36) but its scaling is given in **millivolts per degree**
# (10 mV/°C) -- mixing the two units without converting one to match the
# other throws the whole calculation off by a factor of 1000.
#
# See the reading's [Use Constants for "Magic Numbers"](https://BU-EK125.github.io/EK125/class/Class1.html#use-constants-for-magic-numbers) section for a refresher -- this problem has several (the 0.5V offset, the 10mV/°C scaling, and the 9/5 and 32 in the C-to-F formula).
#
# 🚩 **Common mistake:** getting the Celsius-to-Fahrenheit formula backwards. It's `F = C * 9/5 + 32`, not `C * 5/9 + 32` -- and forgetting the `+ 32` entirely is just as easy to miss.

# %%
# Your code here

# %% [markdown]
# ## Problem 5
#
# Let's say that you wanted to record the temperature of your room over the
# course of 24 hours. Your system senses the temperature every second and
# records the information as a float (8 bytes). How much storage would you
# require to do this? Write Python code to determine your answer in
# reasonable units. Use good programming practice.

# %%
# Your code here
