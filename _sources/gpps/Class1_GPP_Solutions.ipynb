# %% [markdown]
# # Class 1 GPP Solutions: Constants, Variables, Types, and Assignments
# **Group Exercise (Teams of 3)**
#
# Please complete these exercises in groups of three. Whenever you're asked
# to explain something, insert a new markdown cell with your explanation.

# %% [markdown]
# ## Getting Started with Notebooks
#
# See the reading's [Understanding Notebook Structure](https://BU-EK125.github.io/EK125/class/Class1.html#understanding-notebook-structure) and [Markdown Cells vs. Code Cells](https://BU-EK125.github.io/EK125/class/Class1.html#markdown-cells-vs-code-cells) sections for a refresher.

# %% [markdown]
# Click in the code cell below, and then click the Run button above to execute the code. Notice that there is now a number in the square brackets after `In`, and the output has been shown.

# %%
4 + 9

# %% [markdown]
# Enter and execute your own numerical expression here:

# %%
52 - 3 * 4

# %% [markdown]
# ## Indentation and Multi-line Expressions
#
# See the reading's [Example: Multiline Expressions](https://BU-EK125.github.io/EK125/class/Class1.html#example-multiline-expressions) section for a refresher.

# %% [markdown]
# Indentation and spacing is very important in Python. Try executing the code below.

# %%
   1 + 3

# %% [markdown]
# Even though the code was indented, that was OK. Now try executing the code in the next cell. Notice that there are two expressions; the first is not indented but the second one is.

# %%
1 + 3
  4 - 2

# %% [markdown]
# When there is more than one line of code in a cell, they both must be indented to the same level (or not). Go back to the previous code cell and experiment with this. Fix the cell so that it can be executed. Notice also that you only see the result from the second expression.

# %% [markdown]
# Enter an expression over at least two lines, using either parentheses or the backslash. Execute it and make sure it works.

# %%
3 + 5 - \
2

# %%
(3 + 5 -
2)

# %% [markdown]
# ## Variables and Assignment
#
# See the reading's [Declaring Variables in Python](https://BU-EK125.github.io/EK125/class/Class1.html#declaring-variables-in-python) section for a refresher.

# %% [markdown]
# Create a variable named `favnum` and assign your favorite number to it.

# %%
favnum = 33
favnum

# %% [markdown]
# Did your assignment statement work? If you did not already, go back to the code cell and after the assignment statement, just type the name of the variable so that when you execute the cell, the value of the variable will be shown.

# %% [markdown]
# Create an integer variable by assigning a number to it, and then in a second assignment statement increment the variable by 1. Display the result.
#
# See the reading's [Modifying Variables Dynamically](https://BU-EK125.github.io/EK125/class/Class1.html#modifying-variables-dynamically) section for a refresher.

# %%
myvar = 5
myvar = myvar + 1
myvar

# %% [markdown]
# Write a simultaneous assignment statement that will simultaneously assign 0 to a variable named `mysum` and 1 to a variable named `myproduct`. Display the results to make sure it worked.
#
# See the reading's [Simultaneous Assignment](https://BU-EK125.github.io/EK125/class/Class1.html#simultaneous-assignment) section for a refresher.

# %%
mysum, myproduct = 0, 1
print(mysum, myproduct)

# %% [markdown]
# OK, we're going to stop telling you to display the results to make sure they worked. Just always do that! Create a "constant" named `DAYS_IN_WEEK` that stores the number of days in a week.
#
# See the reading's [Constants and Immutability](https://BU-EK125.github.io/EK125/class/Class1.html#constants-and-immutability) section for a refresher.

# %%
DAYS_IN_WEEK = 7
DAYS_IN_WEEK

# %% [markdown]
# Delete your `favnum` variable. Then, type the name `favnum` and examine the error message that you (should) get.
#
# See the reading's [del: Deleting Variables](https://BU-EK125.github.io/EK125/class/Class1.html#del-deleting-variables) section for a refresher.

# %%
del favnum
favnum

# %% [markdown]
# ## The `round()` Function
#
# See the reading's [round(): Rounding Numbers](https://BU-EK125.github.io/EK125/class/Class1.html#round-rounding-numbers) section for a refresher.

# %% [markdown]
# Play around with the round function and make sure that you understand how it works. Testing code is very important. Try real numbers such as 4.2, 4.5, and 4.8. Do they round up? down? Try integers. Try negative and positive numbers.

# %%
round(4.2)

# %%
round(4.5)

# %%
round(4.8)

# %%
round(-4.2)

# %%
round(-4.5)

# %%
round(-4.8)

# %% [markdown]
# So, without entering this code, what would `round(-5.7)` return? Did you test thoroughly enough to be confident of your answer?

# %% [markdown]
# Enter your prediction here:

# %% [markdown]
# **Answer:** -6

# %% [markdown]
# ## `print()` and Data Types
#
# See the reading's [print(): Displaying Output](https://BU-EK125.github.io/EK125/class/Class1.html#print-displaying-output) and [type(): Checking a Variable's Data Type](https://BU-EK125.github.io/EK125/class/Class1.html#type-checking-a-variables-data-type) sections for a refresher.

# %% [markdown]
# Create two number variables and print their values using one print statement.

# %%
num1 = 33
num2 = 11.11
print(num1,num2)

# %% [markdown]
# Create an integer variable and a float variable and print their types.

# %%
int1 = 33
flt1 = 7.7
print(type(int1),type(flt1))

# %% [markdown]
# Create an integer variable `num`, and print the values of `num` raised to the third power, and `num` raised to the fifth power.
#
# See the reading's [Arithmetic Operators](https://BU-EK125.github.io/EK125/class/Class1.html#arithmetic-operators) section for a refresher.

# %%
num = 4
print(num**3, num**5)

# %% [markdown]
# What would be the type of the expression `5 - 4.0`? Check your prediction.

# %%
type(5-4.0)

# %% [markdown]
# ## Division Operators and Scientific Notation
#
# See the reading's [Arithmetic Operators](https://BU-EK125.github.io/EK125/class/Class1.html#arithmetic-operators) and [Numeric Types](https://BU-EK125.github.io/EK125/class/Class1.html#numeric-types) sections for a refresher.
#
# 🚩 **Common mistake:** confusing `/` (float division, always returns a
# `float`) with `//` (integer/floor division). Test both thoroughly with a
# mix of operand types (`int`/`int`, `float`/`float`, mixed) and a mix of
# evenly- and unevenly-divisible numbers -- the type and value of the result
# depends on both.

# %% [markdown]
# Let's examine the division operators. First, test the float division operator `/`. Try it using float operands, int operands, and one float and one int operand. Try it with numbers that divide evenly and numbers that do not divide evenly. Again, testing thoroughly is very important!

# %%
# (open-ended -- test thoroughly; no single fixed answer)

# %% [markdown]
# Now thoroughly test the integer division operator `//`.

# %%
# (open-ended -- test thoroughly; no single fixed answer)

# %% [markdown]
# Finally, thoroughly test the modulus or remainder division operator `%`.

# %%
# (open-ended -- test thoroughly; no single fixed answer)

# %% [markdown]
# Write an expression using scientific notation that would result in the number 30000.

# %%
number = 3e4
number

# %% [markdown]
# ## Putting It All Together

# %% [markdown]
# Create a variable to store the cost of a bagel (let's say $2.25). Create a constant to store the tax rate (let's say 3 percent). What would the total cost of the bagel be? Round this to two decimal places since it's money.

# %%
bagel_cost = 2.25
TAX_RATE = 0.03
total_cost = bagel_cost * (1 + TAX_RATE)
total_cost = round(total_cost, 2)
print("Total cost of the bagel: $", total_cost)

# %% [markdown]
# Using only the integers 2 and 3, try to come up with as many expressions as you can that will result in the integer 9. Be creative!

# %%
3 + 3 + 3
3 * 3
2 * 3 + 3
3 * 2 + 3
2 + 2 + 2 + 3
2 ** 3 + 1
3 ** 2

# %% [markdown]
# Create variables `x = 10` and `y = 3`, and:
# - Calculate their sum and difference.
# - Use `//` and `%` to divide them.

# %%
x = 10
y = 3
print(x + y, x - y)
print(x // y, x % y)

# %% [markdown]
# Assign your name to a variable called `student_name` and print a greeting.

# %%
student_name = "Ada"
print(f"Hello, {student_name}!")

# %% [markdown]
# If you've gotten this far, great job! Your next task is to write a quiz on today's material. Come up with the questions, and test the results. Once you and your partners have written your quizzes, quiz each other with them. You will always spend the full time in class. If you finish the problems before the class period is over, your next task will always be to try to come up with quiz or exam problems. You could also spend your time helping others at your table.
